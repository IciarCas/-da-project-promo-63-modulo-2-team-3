# %%
import pandas as pd
import json

# %%
df = pd.read_json('datos_spotify.json')

df
# Out:
#                            id        artist_name                  track_name  \
# 0      7AlYBA5M9FVXDqN31cbExE     Remedios Amaya                 El zarandeo
# 1      4uqcES2h19TKAXQlciycrO      Nobuo Uematsu          Vamo'alla flamenco
# 2      0z6xGK2u3nSsbk9XeKYwZQ      Maurice Ravel             Flamenco Bolero
# 3      6DjfWx0fXi0uQpedpvaCD9         Mark Towns              After the Rain
# 4      1t91qQaPbOoo4pumaLih4W     Franz Schubert  Tango Serenata (Ständchen)
# ...                       ...                ...                         ...
# 61612  6Lv0uLFhPt6e4qcmoeltAq        Jade Macrae           Ain’t Nobody Home
# 61613  6Lv0uLFhPt6e4qcmoeltAq        Robben Ford           Ain’t Nobody Home
# 61614  4PtUbfBR2U2BC0uUrT9hnM    No Te Va Gustar                    Todo Mal
# 61615  4PtUbfBR2U2BC0uUrT9hnM  Ciro y los Persas                    Todo Mal
# 61616  762E489aCXNDuRg1sZaWmC            Artemas              time alone w u
#
#           genre  year
# 0      flamenco  2000
# 1      flamenco  2000
# 2      flamenco  2000
# 3      flamenco  2000
# 4      flamenco  2000
# ...         ...   ...
# 61612      rock  2026
# 61613      rock  2026
# 61614      rock  2026
# 61615      rock  2026
# 61616      rock  2026
#
# [61617 rows x 5 columns]

# %%
filtro_anio = (df['year'] >=2020) & (df['year'] <= 2025)
filtro_anio
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 61612    False
# 61613    False
# 61614    False
# 61615    False
# 61616    False
# Name: year, Length: 61617, dtype: bool

# %%
df_anio = df[(filtro_anio)]
df_anio
# Out:
#                            id      artist_name               track_name  \
# 44537  5EY4OgQAzbbmLcfX71CYph    Pastora Soler           Demasiado amor
# 44538  7aWPY1wzpVdMUwptggaDCG    Pastora Soler              Non credere
# 44539  44rf2YH4E2bItZmoyRLXhZ    David DeMaría              Días de sol
# 44540  245yCf5jTX1Jgkbr960i6h  Sandra Carrasco                Resistiré
# 44541  6wsGAmBh5t9opcPFwCRamC        Las Niñas  Cuento de la buena pipa
# ...                       ...              ...                      ...
# 59931  0uSMO2S0HwIhapj1FkyoXJ              mgk         times of my life
# 59932  4oONLfYN4mYYWnnQNW0tap         Deftones                cut hands
# 59933  74q9nruImgs45A4xlwckZB    Finn Wolfhard                    Crown
# 59934  07FeCdaFiJYdynFyJW515F     Amira Elfeky         Forever Overdose
# 59935  3kA4NbdN8rA2lDzILYHsci     Milky Chance                  Passion
#
#           genre  year
# 44537  flamenco  2020
# 44538  flamenco  2020
# 44539  flamenco  2020
# 44540  flamenco  2020
# 44541  flamenco  2020
# ...         ...   ...
# 59931      rock  2025
# 59932      rock  2025
# 59933      rock  2025
# 59934      rock  2025
# 59935      rock  2025
#
# [15399 rows x 5 columns]

# %%
filtro_genre = df_anio['genre'].isin(['reggaeton','urbano','rock','k-pop','pop'])
#filtro_genre

df_genre = df_anio[(filtro_genre)]
df_genre
# Out:
#                            id    artist_name         track_name genre  year
# 46238  29jXCAClUxpYQJeFXcNdKt   Boyce's Road  What an Afternoon   pop  2020
# 46239  1LaSKOvzfdoa9nG4mgPlL5   Boyce's Road           Hot Wind   pop  2020
# 46240  0VajyeVRgg1v3gCKZk1lhT   Boyce's Road      Reggie Dwight   pop  2020
# 46241  57yK47ckLMIcTBp1lKULTQ   Boyce's Road         Without Me   pop  2020
# 46242  19UCTc97ctOhozBBYh98hw   Boyce's Road          Wakin' Up   pop  2020
# ...                       ...            ...                ...   ...   ...
# 59931  0uSMO2S0HwIhapj1FkyoXJ            mgk   times of my life  rock  2025
# 59932  4oONLfYN4mYYWnnQNW0tap       Deftones          cut hands  rock  2025
# 59933  74q9nruImgs45A4xlwckZB  Finn Wolfhard              Crown  rock  2025
# 59934  07FeCdaFiJYdynFyJW515F   Amira Elfeky   Forever Overdose  rock  2025
# 59935  3kA4NbdN8rA2lDzILYHsci   Milky Chance            Passion  rock  2025
#
# [4671 rows x 5 columns]

# %%
df
# Out:
#                            id        artist_name                  track_name  \
# 0      7AlYBA5M9FVXDqN31cbExE     Remedios Amaya                 El zarandeo
# 1      4uqcES2h19TKAXQlciycrO      Nobuo Uematsu          Vamo'alla flamenco
# 2      0z6xGK2u3nSsbk9XeKYwZQ      Maurice Ravel             Flamenco Bolero
# 3      6DjfWx0fXi0uQpedpvaCD9         Mark Towns              After the Rain
# 4      1t91qQaPbOoo4pumaLih4W     Franz Schubert  Tango Serenata (Ständchen)
# ...                       ...                ...                         ...
# 61612  6Lv0uLFhPt6e4qcmoeltAq        Jade Macrae           Ain’t Nobody Home
# 61613  6Lv0uLFhPt6e4qcmoeltAq        Robben Ford           Ain’t Nobody Home
# 61614  4PtUbfBR2U2BC0uUrT9hnM    No Te Va Gustar                    Todo Mal
# 61615  4PtUbfBR2U2BC0uUrT9hnM  Ciro y los Persas                    Todo Mal
# 61616  762E489aCXNDuRg1sZaWmC            Artemas              time alone w u
#
#           genre  year
# 0      flamenco  2000
# 1      flamenco  2000
# 2      flamenco  2000
# 3      flamenco  2000
# 4      flamenco  2000
# ...         ...   ...
# 61612      rock  2026
# 61613      rock  2026
# 61614      rock  2026
# 61615      rock  2026
# 61616      rock  2026
#
# [61617 rows x 5 columns]

# %%
generos_unicos = df_anio['genre'].unique() 
print(generos_unicos)
# Out:
# ['flamenco' 'hip-hop' 'indie' 'latin' 'orchestra' 'pop' 'rap' 'reggaeton'
#  'rock' 'tango']

# %%
# En resumen:

filtro_anio = (df['year'] >=2020) & (df['year'] <= 2025)
filtro_genre = df['genre'].isin(['reggaeton','hip-hop','rock','indie','pop'])

df_filtrado = df[(filtro_anio & filtro_genre)]
df_filtrado
# Out:
#                            id    artist_name  \
# 44600  1XVml2ioz9HQbDONsbSaqi          Yusei
# 44601  78SeXVRJ7KCqVmOwTiFjnI       Bizarrap
# 44602  78SeXVRJ7KCqVmOwTiFjnI   NATHY PELUSO
# 44603  0Y6FnT5WeEVrPBwI1uJyfr       Al Safir
# 44604  1V8XneTrX6kKeoxYbk4x6h      Bad Bunny
# ...                       ...            ...
# 59931  0uSMO2S0HwIhapj1FkyoXJ            mgk
# 59932  4oONLfYN4mYYWnnQNW0tap       Deftones
# 59933  74q9nruImgs45A4xlwckZB  Finn Wolfhard
# 59934  07FeCdaFiJYdynFyJW515F   Amira Elfeky
# 59935  3kA4NbdN8rA2lDzILYHsci   Milky Chance
#
#                                           track_name    genre  year
# 44600                              Hopeless Romantic  hip-hop  2020
# 44601  Nathy Peluso: Bzrp Music Sessions, Vol. 36/66  hip-hop  2020
# 44602  Nathy Peluso: Bzrp Music Sessions, Vol. 36/66  hip-hop  2020
# 44603                                  Young Sinatra  hip-hop  2020
# 44604                                Hablamos Mañana  hip-hop  2020
# ...                                              ...      ...   ...
# 59931                               times of my life     rock  2025
# 59932                                      cut hands     rock  2025
# 59933                                          Crown     rock  2025
# 59934                               Forever Overdose     rock  2025
# 59935                                        Passion     rock  2025
#
# [10376 rows x 5 columns]

# %%
#df_filtrado.to_json('datos_filtrados.json', orient='records')

# %%
lista = list(df_filtrado['artist_name'])
#lista_sin_duplicados = list(dict.fromkeys(lista))
lista_sin_duplicados = list(set(lista))
print(len(lista))
print(len(lista_sin_duplicados))
lista_sin_duplicados
# Out:
# 10376
# 3827
# ['Joey Bada$$',
#  'Jamie Principle',
#  'DELLAFUENTE',
#  'Pabllo Vittar',
#  'Kakkmaddafakka',
#  'Jon Z',
#  'Alonzo',
#  'Bomba Estéreo',
#  'Warma',
#  'ÁSDÍS',
#  'Mickey Ojo Rojo Sg',
#  'Mufasa & Hypeman',
#  '3robi',
#  'Hard GZ',
#  'Ñejo',
#  "Rag'n'Bone Man",
#  'GT',
#  'Nirvana',
#  'Peje',
#  'SBO',
#  'Polo G',
#  'Vera Fauna',
#  'Funky',
#  'Chief Keef',
#  'Pe2ny',
#  'Leonel García',
#  'PFV',
#  'Day We Ran',
#  'Jaya',
#  'TTRRUUCES',
#  'R2',
#  'Noyzee',
#  'Seori',
#  'CA7RIEL & Paco Amoroso',
#  'lil ÜBER',
#  'ProdWithFlavor',
#  'El Sebas de la Calle',
#  'Angel Guaraca',
#  'Quevedo',
#  'Adam Levine',
#  'DJ Nano',
#  'I Prevail',
#  'Sped Up',
#  'Miki Martz',
#  'La Rvfleuze',
#  'RUSLANA',
#  'L7NNON',
#  'ШЕFF',
#  'Fink',
#  'The Rumjacks',
#  'Cordae',
#  'Catching Flies',
#  'Loraine James',
#  'El Loco Abrahan "LA ORQUESTA JOVEN"',
#  'Noshows',
#  'Ю.Г.',
#  'GAULOIS',
#  'maye',
#  'TEZZ',
#  'NF',
#  'Friday Pilots Club',
#  'Soni Malaj',
#  'Lapili',
#  "Kya Monee'",
#  'Lewis Capaldi',
#  'House Of Pain',
#  'Munch Lauren',
#  'Beartooth',
#  'Booski3',
#  'Sara de las Chuches',
#  'Megan Thee Stallion',
#  'Lil Philthy',
#  'Drug Store Romeos',
#  'austin fox 狐',
#  'Beéle',
#  'Rio Branco',
#  'Jamby El Favo',
#  'Rondodasosa',
#  'Mk.gee',
#  'Lucas Otero',
#  'C-Rayz Walz',
#  'Neto Peña',
#  'Booska-P',
#  'Rex Orange County',
#  'Chayanne',
#  'Richie Kotzen',
#  'Calum Scott',
#  'Lune Mstyles',
#  'Roosevelt',
#  'Marisa Valle Roso',
#  'Yahalom',
#  'Sports',
#  'Puño Dragón',
#  'Klein Fortuin',
#  'Oasis',
#  'Los Jinetes del Trópico',
#  'Tufic',
#  'Anderson .Paak',
#  'Zea Mays',
#  'Khalil Brems',
#  'Latto',
#  'Jerry Di',
#  'Patrick Watson',
#  'Ghostface Killah',
#  '$ean Wire',
#  'Primer',
#  'Sevn Alias',
#  'poisonhxrzy',
#  'Carlos Vives',
#  'Jonathan Cloud',
#  'Galantis',
#  'Yung Sarria',
#  'Käärijä',
#  'Sebastian Yatra',
#  'ELYELLA',
#  "Crem'e",
#  'Ede',
#  '21 Savage',
#  'Milicia',
#  'Dopamine',
#  'Pce Bj',
#  'VK Blanka',
#  'MICO',
#  'Isaiah Rashad',
#  'Sfera Ebbasta',
#  'Sanguijuelas del Guadiana',
#  'Serú Girán',
#  'Mala Gestión',
#  'Koe Wetzel',
#  'Quessswho',
#  'CMDWN',
#  'Joeelg',
#  'Pol 3.14',
#  'Ariana Grande',
#  'Key Glock',
#  'Juicy B',
#  'Мойша Эскобар',
#  'Maye Star',
#  'Hijos de la Ruina',
#  'Pirlo',
#  'Zenden Lavon',
#  "Lal'Ba",
#  'Benjamin Steer',
#  'Métricas Frías',
#  'Verónica Romero',
#  'TL Jones',
#  'Punkinloveee',
#  'Rvssian',
#  'La Pantera',
#  'HARDY',
#  'Rammstein',
#  'Royal Blood',
#  'Brayzee Loww',
#  'The Goo Goo Dolls',
#  'Slayter',
#  'Sash!',
#  'MAAPS',
#  'Passenger',
#  'Smith/Kotzen',
#  'Raffaella',
#  'Israel Suárez "Piraña"',
#  'Joey Valence & Brae',
#  "Iñaki Antón 'Uoho'",
#  '6arelyhuman',
#  'Ptazeta',
#  'Young Miko',
#  'Grover Washington, Jr.',
#  'Take Care',
#  'Briston Maroney',
#  'Myke Towers',
#  'Pvrx',
#  'IDOIA',
#  'Lady Gaga',
#  'Peter Hook',
#  'Gloosito',
#  'Boza',
#  'The Weeknd',
#  'Shubh',
#  'ONE OK ROCK',
#  'Talwiinder',
#  'Calcutta ',
#  'Mda',
#  'Cecy Narvaez',
#  'lil eli young bapestah',
#  'Alicia Renee',
#  'Will Paquin',
#  'Recyclone',
#  'Fazzini',
#  'Hef',
#  'Poncho K',
#  'Mallrat',
#  'Ashnikko',
#  'Kings of Leon',
#  'JessB',
#  'DJ Naughtyboyy',
#  'K/DA',
#  'Wisin',
#  'Slum Drip',
#  'Haze',
#  'GARZI',
#  'Juancho Sidecars',
#  'KYLE',
#  'Elvis Presley',
#  'El Mató a un Policía Motorizado',
#  'Emanero',
#  'Glassjaw',
#  'Of Monsters and Men',
#  'Ryda',
#  'Los Bravos Del Ande',
#  'Cosita Wena',
#  'Alex P.',
#  'Porch Light',
#  'Cariño',
#  'Rozalla',
#  'AK-47',
#  'Jean',
#  'Mexzo',
#  'The Surfaris',
#  'Nuno Bettencourt',
#  'BLNCO',
#  'Lonely God',
#  'Night Skinny',
#  'Slimm',
#  'jayo',
#  'PNAU',
#  'DJ Mzenga Man',
#  'Our Mirage',
#  'Descendientes',
#  'Haley Joelle',
#  'Cocteau Twins',
#  'The Jacka',
#  'Loquillo',
#  'Mansa Lufer',
#  'Yung Verbal',
#  'Mac DeMarco',
#  'GREX',
#  'Almanegra',
#  'Nuka',
#  'King Macarella',
#  'Balti',
#  'Big Red Machine',
#  'Vonlaynee',
#  'Tom Misch',
#  'Vizual Dealer',
#  'La Roux',
#  'Paul McCartney',
#  'Daddy DJ',
#  'late night drive home',
#  'SRNO',
#  '10cellphones',
#  'ELLIS QUINN',
#  'Natalia Lacunza',
#  'Birdz',
#  'PoppasPlanet',
#  'UKNWN',
#  'Pbc Rell',
#  'Asal',
#  'Sampha',
#  'Alberto Toral',
#  'Loathe',
#  'Local Boy',
#  'Jay Lewis',
#  'Dodo',
#  'Hypaton',
#  'Lopes',
#  'Julien Baker',
#  'Una María',
#  'vangoura',
#  'Isabel Aaiún',
#  'removeface',
#  'Barry B',
#  'Ed Prosek',
#  'TerJoy',
#  'Henry Morris',
#  "Guns N' Roses",
#  'Naim',
#  'David Bowie',
#  'Schur',
#  'Galvan Real',
#  'Prod by Ice G',
#  'Dax',
#  'No Sun',
#  'Lamatrix',
#  'Adrianne Lenker',
#  'Princess Chelsea',
#  'Seun Kuti',
#  'Pslow',
#  'Werenoi',
#  'Wise',
#  'makko',
#  'Cuco',
#  'Kodak Black',
#  'Eflexx',
#  'Skitz Dibiase',
#  'Gunship',
#  'Salistre',
#  'VillaBanks',
#  'Piti Fernández',
#  'thasup',
#  'Mikel Izal',
#  'Rusherking',
#  'Le Bober',
#  'Fraser T. Smith',
#  'Nazar',
#  'sign crushes motorist',
#  'Loe Shimmy',
#  'Chrissy Costanza',
#  'Kidd Keo',
#  'ZEP',
#  'Lola Indigo',
#  'prod.akamini!',
#  'Nevertel',
#  'Luis7Lunes',
#  'Chillout Lounge',
#  '2nd Roof',
#  'Rienda Suelta',
#  'Wes',
#  'RONNY J',
#  'ROA',
#  'MATTIAS HAGELBERG',
#  'Portugal. The Man',
#  'Adele',
#  'ADLR',
#  'Point North',
#  'Saigon',
#  'Clipse',
#  'John Mayer',
#  'The Shadow',
#  'Nicky Jam',
#  'Maria Becerra',
#  'Lucky Paul',
#  '9lives',
#  'Reece Lache’',
#  'Terry Borderline',
#  'Gimma',
#  'EYECON',
#  'Alpha Romeo',
#  'La Decada Prodigiosa',
#  'Eslabon Armado',
#  'C Grizzy',
#  'Fontaines D.C.',
#  'Maes',
#  'Parkineos',
#  'Kwangjae Jeon',
#  'Tayla Parx',
#  'Navikx',
#  'Doble Porcion',
#  'Vigos',
#  'Recycled J',
#  'Artist Anhysbys',
#  'Moncho Chavea',
#  'Ronpe 99',
#  'Mon Laferte',
#  'Bebe Rexha',
#  'I.N',
#  'Connor Kauffman',
#  'Bob Moses',
#  'Alan Walker',
#  'Yorssy',
#  'Nina de Juan',
#  'Jordana',
#  'Haley Heynderickx',
#  'Mc Mabon',
#  'Bossa Bros',
#  'Optiks',
#  'Andrew Choi',
#  'Issa Ali',
#  'Genesis Renji',
#  'Sam Feldt',
#  'Sean Focus',
#  'The Offspring',
#  'Bersuit Vergarabat',
#  'LA ÉLITE',
#  'HUNTR/X',
#  'Las Chuches',
#  'horrormovies',
#  'El sonido del javier',
#  'Secreto "El Famoso Biberon"',
#  'Franky Style',
#  'Baby Keem',
#  'Camb',
#  'Lykke Li',
#  'Rotten XIII',
#  'JC Reyes',
#  'Kenny Die',
#  'Joris Voorn',
#  'Brianna Perry',
#  'MNEK',
#  'Dropkick Murphys',
#  'ORO600',
#  'Dobazznet',
#  'GAMPER & DADONI',
#  'Tristian Workman',
#  'Duran Duran',
#  'Huecco',
#  'GHOSTWOMAN',
#  'Tiësto',
#  'BALTHVS',
#  'J Scope',
#  'Kutxi Romero',
#  'Portair',
#  'Mumford & Sons',
#  'ROOM9',
#  '50 Cent',
#  'Sinkope',
#  'Parquesvr',
#  'Negro Jari',
#  'The Happy Fits',
#  'Mammoth',
#  'Paul Alone',
#  'Yellow House',
#  'Javypablo',
#  'Eu93ne',
#  'Our Last Night',
#  'Never Dull',
#  'Richy Mitch & The Coal Miners',
#  'Lila Downs',
#  'Besmaya',
#  'Dani Martín',
#  'Charlotte Sands',
#  'Lizzo',
#  'AVA',
#  'Suu',
#  'MC Paulin da Capital',
#  'Big Loww',
#  'Jack Danz',
#  'Faxu',
#  'Iziou',
#  'Al Safir',
#  'Silvana Estrada',
#  'Alumni Cloud',
#  'Canserbero',
#  'Arnav',
#  'MikS',
#  'Segway',
#  'Rauw Alejandro',
#  'ALICIA RENEE',
#  'Alberto Tapia',
#  'NEIKED',
#  'Kkkevin',
#  'Joesef',
#  'Maparche',
#  'King Von',
#  'Searows',
#  'Mista LT',
#  'Garena Free Fire',
#  'Arroba Nat',
#  'Brown_buddha',
#  'Major Lazer',
#  'Genesis Elijah',
#  'ElDimas',
#  'Amenoskuarto',
#  'Xenturion Prime',
#  'Diagnóstico Binario',
#  'Gonzalo Genek',
#  'V1V1D',
#  'Miranda',
#  'もっさ',
#  'Lil Mosey',
#  'bigmcenroe',
#  'Main Source',
#  'Tyla Yaweh',
#  'Hollow Ship',
#  'Obie Wanshot',
#  'DCup',
#  'almost monday',
#  'Cam Meekins',
#  'Morning Drivers',
#  'RAYE',
#  'Shahrukh Masnad',
#  'Tornillo',
#  'Till Lindemann',
#  'Beto Sierra',
#  'Tutu',
#  'Capo Fenadi',
#  'Empire Of The Sun',
#  'Mystique',
#  'Tony Boy',
#  'juju<3',
#  'Scott Bathgate',
#  'V',
#  'Pascal Letoublon',
#  'Banda Do Sul',
#  'Kings of Regueton',
#  'Bizarrap',
#  'Gazzelle',
#  'kets4eki',
#  '2t',
#  'Sia',
#  'Dave East',
#  'Jaguayano',
#  'Mick Mars',
#  'Enol',
#  'Los Zopilotes Txirriaos',
#  'Xtend',
#  'Fulminacci',
#  'Lil GZ',
#  'ShrekDiMC',
#  'De La Ghetto',
#  'Marvin',
#  'Bubaseta',
#  'DA Uzi',
#  'Summer Walker',
#  'Aughra',
#  'Jean Tonique',
#  'Tomas Chris',
#  'Mous-K',
#  'Jocelyn & Chris Arndt',
#  'Estopa',
#  'Ado',
#  'jxdn',
#  'Siloé',
#  'Mach-Hommy',
#  'KANA-BOON',
#  'Kyle Alessandro',
#  'Neutro Shorty',
#  'Tones And I',
#  'Sigur Rós',
#  'Culture Wars',
#  'Freya Skye',
#  'INNMIR',
#  'Hanzel La H',
#  'The Rumpled',
#  '24 Kara',
#  'Kwasi',
#  'Lynyrd Skynyrd',
#  'Eurotripp',
#  'blackbear',
#  'KIDDO',
#  'Night Tapes',
#  'Jords',
#  'Dr. López',
#  'ZEG P',
#  'Luke Bar$',
#  'Rex Royal',
#  'The Kidd',
#  'Ire',
#  '615 Exclusive',
#  'David Rees',
#  "Somebody's Child",
#  "Aunt Cynthia's Cabin",
#  'Shiva',
#  'Orslok',
#  'Toaka',
#  'Juancho Marqués',
#  'Post Malone',
#  'Sun Room',
#  'Neelo',
#  'Good Kid',
#  'Wolftyla',
#  'ilo 7araga',
#  'Gerard Aledo',
#  'Tame Impala',
#  'The Lazy Jesus',
#  'jeney',
#  'Playboi Carti',
#  'Paula Mattheus',
#  'Mae Muller',
#  'Elyanna',
#  'Shauly',
#  'El Barrio',
#  '112',
#  'Mt. Joy',
#  'Disclosure',
#  'Alicia te quiero',
#  'Silvestre Dangond',
#  'Ice One',
#  'Yesan 雪山',
#  'Khaled',
#  'Joji',
#  'Coldplay',
#  '8 Zipp',
#  'Smiley',
#  'Kali Uchis',
#  'Demzy',
#  'Sosad',
#  'Showme',
#  'Lewis OfMan',
#  'Patrick Wilson',
#  'Beendo Z',
#  'Roberto Ferrante',
#  'Ismael Serrano',
#  'Pressure 9X19',
#  'Marco Antonio Solís',
#  'The Hives',
#  'Selene',
#  'Alejo',
#  'María Cortés',
#  'Inhaler',
#  'Yves Tumor',
#  'KC Ortiz',
#  'Los G4',
#  'Alizzz',
#  'Sosa La M',
#  'Amenazzy',
#  'Messiah',
#  'SPONSOR DIOS',
#  'Begut',
#  'Alvaro Soler',
#  'OTP',
#  'Atarejep',
#  'Armani White',
#  'A Flock Of Seagulls',
#  'Nanpa Básico',
#  'noahjooda',
#  'ELLEGARDEN',
#  'Nates Beats',
#  'Gazo',
#  'T.Y.S',
#  'João Carlos Martins',
#  'Blanca Mudel',
#  'Fondo Blanco',
#  'The Irrepressibles',
#  'Slkrack',
#  'Oualid',
#  'MocroManiac',
#  'Mad Dogg',
#  'aldn',
#  'Nines',
#  'Wallows',
#  'Remik Gonzalez',
#  'Sôber',
#  'Ruzzi',
#  'DJ Ruso',
#  'Clover!',
#  'Santa Suerte',
#  'linhchou',
#  'Anyme023',
#  'C.O.S.',
#  'Jin',
#  'Travis Barker',
#  'Cde Ndamburanduwe',
#  'ISM',
#  'Devon Hendryx',
#  'Nou Nueve',
#  'Solo Kei',
#  'Thiago Sub',
#  'Mareux',
#  'Jonas Blue',
#  'Dj GM',
#  'DrefQuila',
#  'Rubin',
#  'Yan Block',
#  'ivri',
#  'Lord T',
#  'Rowma',
#  'La Femme',
#  'Paco Soto',
#  'Kalash',
#  'SUICIDAL-IDOL',
#  'TRISTÁN!',
#  'Beneath the Neon Sky',
#  'Kinky Bwoy',
#  'sped up nightcore',
#  'Alcolirykoz',
#  'Daddyisme',
#  'LoneWolf',
#  'Esteve',
#  'Lil Wayne',
#  'Pierce The Veil',
#  'Ovy On The Drums',
#  'Pignoise',
#  'Albert Hammond Jr',
#  'JAWNY',
#  'Mbongo',
#  'Ruggedman',
#  'R.E.M.',
#  'Tempo',
#  'Mr. Kilombo',
#  'Rozalén',
#  'Roy Bee',
#  'Tenda',
#  'The Orion Experience',
#  'llvna',
#  'Funny$money',
#  'Chuyin',
#  'Aimer',
#  'Milly',
#  'Sky Bouy',
#  'Milky Chance',
#  'Dropped Out',
#  'julie',
#  'Pirris Sosa',
#  'Elams',
#  'HWASA',
#  'Topic',
#  'Anubiis',
#  'noturgf',
#  'Turnstile',
#  'Jairo deRemache',
#  'Kore',
#  'Erny',
#  'Piso 21',
#  'David Bisbal',
#  'Juls Cattáneo',
#  'Dorian',
#  'Kehlani',
#  'Central Cee',
#  'ABBBOSE',
#  'Detroit Rap News',
#  'KARDO',
#  'Bayronn Caicedo',
#  'Ziggy Alberts',
#  'Babyface Ray',
#  'Erik Gevorgyan',
#  'ME THE TIGER',
#  'Stewie G',
#  'Sidhu Moose Wala',
#  'Jung Kook',
#  'Lola Young',
#  'luvwillow',
#  'Itzik Shamli',
#  'Zoe Gotusso',
#  'NerdOut',
#  'A$AP Rocky',
#  'Mon Rovîa',
#  'Ele A El Dominio',
#  'Steph Kapela',
#  'The Strokes',
#  'King Shaun',
#  'Black Stone Cherry',
#  'Rimkus',
#  'Flow G',
#  'Mr. Turner',
#  'Good Neighbours',
#  'ATEEZ',
#  'OLAS',
#  'MR. LU*',
#  'BAMBINI CATTIVI',
#  'DTB-Sav',
#  'Vance Joy',
#  'A. G. Cook',
#  'Gorka Urbizu',
#  'MAIRENA',
#  'Abitola',
#  'Dudi',
#  'Embusteros',
#  'La Hasba22',
#  'Pablo Cuesta',
#  'Demarco Flamenco',
#  'Big Thief',
#  'Dom Corleo',
#  'J-Xtreme',
#  'Kashlo',
#  'Hadrian',
#  'Seraphine',
#  'Michael Jackson',
#  'Mama Dousha',
#  'Conscious Route',
#  'Black Thought',
#  'skaiwater',
#  'NewJeans',
#  'Selfless Homage',
#  'DARGZ',
#  'Dua Lipa',
#  'Sam Tinnesz',
#  'Tensei One',
#  'Lowswimmer',
#  'Raule',
#  'Chef Boy',
#  'Luis Fercán',
#  'Fraderita',
#  'JHAYCO',
#  'Julian Perretta',
#  'John Cale',
#  'imase',
#  'Luke Sital-Singh',
#  'Hyunjin',
#  'Bleed Token',
#  'Sacky',
#  'Caloncho',
#  'Jeris Johnson',
#  'Ravyn Lenae',
#  'B-Real',
#  'GARABATTO',
#  'Sofía Reyes',
#  'YOVNGCHIMI',
#  'Mesita',
#  'Bunbury',
#  'Jesse Baez',
#  'Raul Camacho',
#  'Murder',
#  'Rich Vagos',
#  'Antonio Carmona',
#  'Baby Gang',
#  'Pitingo',
#  'KHEIS',
#  'Cam Murdoch',
#  'Ergo Pro',
#  'José Alma',
#  'Katie Gregson-MacLeod',
#  'Slim Jxmmi',
#  'The Paper Kites',
#  'Tiakola',
#  'Linkin Park',
#  'Jarv Dee',
#  'Achille Lauro',
#  'Ninho',
#  'Skitz',
#  'LosNiñosDelCaminito',
#  'Street Plug',
#  'Factor',
#  'Transparent Arts',
#  'KEM',
#  'glaive',
#  'Reality',
#  'JISOO',
#  'Paco Martin',
#  'Nine Inch Nails',
#  'Mr Phormula',
#  'Kauta',
#  'Byron Solis',
#  'Balu Brigada',
#  'The Lumineers',
#  'Neves17',
#  'jnhygs',
#  'Mounika.',
#  'Depakote',
#  'Solitario Soldado',
#  'The K',
#  'Amber Mark',
#  'Nickzzy',
#  'Saïf',
#  'Kofs',
#  'Eva Marti',
#  'Tilt',
#  'Motörhead',
#  'Marracash',
#  'Sabino',
#  'Sonz of Serpent',
#  'Tyler, The Creator',
#  'AnnenMayKantereit',
#  'HUMBE',
#  'ELENA ROSE',
#  'Joejoe',
#  'Myles Smith',
#  'Kaze',
#  'Ty Dolla $ign',
#  'KISS',
#  'BIG KAY SMG',
#  'Lil Yachty',
#  'Nettspend',
#  'Caiola',
#  'Grim Pil',
#  'Lil Tjay',
#  'Zecca',
#  'LieVin',
#  'Carlota Flâneur',
#  'Infinite Mass',
#  'Misha Mansoor',
#  'Ásgeir',
#  'Queens of the Stone Age',
#  'Gorilla Mode Dezz',
#  'Jesse & Joy',
#  'Antonio Orozco',
#  'BeeJay',
#  'Tigerhorse',
#  'Emilia',
#  'Surf Hat',
#  'Shaboozey',
#  'Pipo Beatz',
#  'Lady Ma Belle',
#  'Sarz',
#  'Annia',
#  'Afromak',
#  'Munic HB',
#  'Cali Y El Dandee',
#  'Jonah Kagen',
#  'WIXO & LA2S',
#  'Freshy Kanal',
#  'Soleá Morente',
#  'Rhye',
#  'Hayd',
#  'tatool',
#  'Temples',
#  'Jorge Celedón',
#  'BLOND:ISH',
#  'Treintisiete',
#  'Big Sean',
#  'Maude Latour',
#  'Edurne',
#  'Noah Rinker',
#  'Afterclass',
#  'BABYMONSTER',
#  'Santiago Motorizado',
#  'Placebo',
#  'Dadi',
#  'Nadal015',
#  'League of Legends',
#  'Kekz',
#  'Troye Sivan',
#  'David Kushner',
#  'Chezile',
#  'Soso Maness',
#  'Peter McPoland',
#  'Michal',
#  'Matt Berninger',
#  'Ronald Morrera',
#  'Grrrlcheez',
#  'Peredius',
#  'Kaia Lana',
#  'alt-J',
#  'glwzbll',
#  'Freeze corleone',
#  'Sami Duque',
#  'AN TY',
#  'LaGlorya',
#  'Gloria Trevi',
#  'Kevin Krust',
#  'Camila Cabello',
#  'Lake Street Dive',
#  'CYRIL',
#  'Ink',
#  'OG FatTae',
#  'Tanna Leone',
#  '¥$',
#  'Young Martino',
#  'Locos De Atar',
#  'Nicki Minaj',
#  'BAXIAN',
#  'Bon Entendeur',
#  'Bame',
#  'Travis Birds',
#  'Djerv',
#  'mdot ebk',
#  'Louie Ray',
#  'Oscar Maydon',
#  'Alejandro Astola',
#  'Miss Caffeina',
#  'ACRU',
#  'ZetaZeta',
#  'Caleb Aronson',
#  'Russy',
#  'Tivi Guns',
#  'Pablo Alborán',
#  'Chase Manhattan',
#  'Los Auténticos Decadentes',
#  'Slappy Av',
#  'Masilo The Healer',
#  'DePol',
#  'YOASOBI',
#  'Kacey Musgraves',
#  'Indio Solari',
#  'Ice Spice',
#  'ovg!',
#  'Chinese American Bear',
#  'The Pretty Reckless',
#  'Lalo Ebratt',
#  'Anabel Lee',
#  'I-Ace',
#  'TBF',
#  'Lil From',
#  'Dangest',
#  'Nahuel Pennisi',
#  'Metro Boomin',
#  'Amira Elfeky',
#  'Cage The Elephant',
#  'Los Diablitos',
#  'Wyzaker',
#  'Clutch',
#  'Ozarus',
#  'lksvlkgd',
#  'Víctor Cabezuelo',
#  'Zaidbreak',
#  'Communicant',
#  'La Cantera',
#  'Candela Gómez',
#  'JVKE',
#  'Brytiago',
#  'Madman the Greatest',
#  'Orodembow',
#  'Snoop Dogg',
#  'KAROL G',
#  'Alexander Padei',
#  'BM',
#  'Bilouki',
#  'COQE',
#  'REI AMI',
#  'IZARO',
#  'Poligamia',
#  'Prem Dhillon',
#  'Cosmic Wacho',
#  'Sten Joddi',
#  'Anıl Emre Daldal',
#  'Blake',
#  'MoStack',
#  'Diddy',
#  'Miquel Angel',
#  'The 1975',
#  'Frances Forever',
#  'Waste',
#  'Leiva',
#  '167 Gang',
#  'Manuel Cortés',
#  'Dame Grease',
#  'Dj Sonni',
#  'Haiden Henderson',
#  'Funambulista',
#  'Rojuu',
#  'Omg Oumy Gueye',
#  ...]

# %%
with open("lista_artistas.json", "w", encoding="utf-8") as archivo:
    json.dump(lista_sin_duplicados, archivo, indent=4, ensure_ascii=False)
