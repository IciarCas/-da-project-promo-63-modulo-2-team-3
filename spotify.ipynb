# %%
import pandas as pd
import json

# %%
df = pd.read_json('definitivo.json')

df
# Out:
#                            id        artist_name                  track_name  \
# 0      7AlYBA5M9FVXDqN31cbExE     Remedios Amaya                 El zarandeo
# 1      4uqcES2h19TKAXQlciycrO      Nobuo Uematsu          Vamo'alla flamenco
# 2      0z6xGK2u3nSsbk9XeKYwZQ      Maurice Ravel             Flamenco Bolero
# 3      6DjfWx0fXi0uQpedpvaCD9         Mark Towns              After the Rain
# 4      1t91qQaPbOoo4pumaLih4W     Franz Schubert  Tango Serenata (Ständchen)
# ...                       ...                ...                         ...
# 61612  6Lv0uLFhPt6e4qcmoeltAq        Jade Macrae           Ain’t Nobody Home
# 61613  6Lv0uLFhPt6e4qcmoeltAq        Robben Ford           Ain’t Nobody Home
# 61614  4PtUbfBR2U2BC0uUrT9hnM    No Te Va Gustar                    Todo Mal
# 61615  4PtUbfBR2U2BC0uUrT9hnM  Ciro y los Persas                    Todo Mal
# 61616  762E489aCXNDuRg1sZaWmC            Artemas              time alone w u
#
#           genre  year
# ...

# %%
filtro_anio = (df['year'] >=2005) & (df['year'] <= 2009)
filtro_anio
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 61612    False
# 61613    False
# 61614    False
# 61615    False
# 61616    False
# Name: year, Length: 61617, dtype: bool

# %%
df_anio = df[(filtro_anio)]
df_anio
# Out:
#                            id      artist_name                 track_name  \
# 9147   0YXYaZ0ZiZNE3QPGAVN7p6        Angelillo          Serranía de Ronda
# 9148   2Yt7e4bG5sO3IEA5YjZFIx        Angelillo                 Chiclanera
# 9149   3MDEPsKCGyyMqFPGjW9DLJ        Angelillo             Paco el Minero
# 9150   41qr4tgURYfL7Yus7lBWVP        Angelillo            Granada Morisca
# 9151   3sizJPuTf0lcUENHs56PrP        Angelillo                Mi Recuerdo
# ...                       ...              ...                        ...
# 19432  4gnhILYPGdbLDuwdhPSRJq      Georg Huber                A media luz
# 19433  7LJ6QmI9qX2AudFB8YVlpc    Tatsuo Sasaki    HIstoire du tango: Cafe
# 19434  7LJ6QmI9qX2AudFB8YVlpc  Michiko Noguchi    HIstoire du tango: Cafe
# 19435  38LRxEVND9IJyUEGvJar8E    Tatsuo Sasaki  Histoire du tango: Bordel
# 19436  38LRxEVND9IJyUEGvJar8E  Michiko Noguchi  Histoire du tango: Bordel
#
#           genre  year
# 9147   flamenco  2005
# 9148   flamenco  2005
# ...

# %%
filtro_genre = df_anio['genre'].isin(['hip-hop','rock','latin','pop'])
#filtro_genre

df_genre = df_anio[(filtro_genre)]
df_genre
# Out:
#                            id    artist_name  \
# 9177   1PS1QMdUqOal0ai3Gt7sDQ     Kanye West
# 9178   1PS1QMdUqOal0ai3Gt7sDQ     Jamie Foxx
# 9179   0jukvcN4fAGAgtkYVgLR9Z           SFDK
# 9180   2dxjKgT0li4qBI3QwuN9Ih     Kanye West
# 9181   2dxjKgT0li4qBI3QwuN9Ih    Lupe Fiasco
# ...                       ...            ...
# 19425  3h4JgBHcWM7A4CBVI6csau        Skillet
# 19426  0nx12KXHohiyLRqO5qfV2k  Mark Knopfler
# 19427  6gVH9jHl5Xpxxl4gVVrEkE        Nirvana
# 19428  6ZpbDCTXLlorzMgv8BEAHu      New Limit
# 19429  3K2dcFU3Wc2yAtC74b7d0H          Kryss
#
#                                            track_name    genre  year
# 9177                                      Gold Digger  hip-hop  2005
# 9178                                      Gold Digger  hip-hop  2005
# 9179                                     El Niño Güei  hip-hop  2005
# 9180                                    Touch The Sky  hip-hop  2005
# 9181                                    Touch The Sky  hip-hop  2005
# ...

# %%
df
# Out:
#                            id        artist_name                  track_name  \
# 0      7AlYBA5M9FVXDqN31cbExE     Remedios Amaya                 El zarandeo
# 1      4uqcES2h19TKAXQlciycrO      Nobuo Uematsu          Vamo'alla flamenco
# 2      0z6xGK2u3nSsbk9XeKYwZQ      Maurice Ravel             Flamenco Bolero
# 3      6DjfWx0fXi0uQpedpvaCD9         Mark Towns              After the Rain
# 4      1t91qQaPbOoo4pumaLih4W     Franz Schubert  Tango Serenata (Ständchen)
# ...                       ...                ...                         ...
# 61612  6Lv0uLFhPt6e4qcmoeltAq        Jade Macrae           Ain’t Nobody Home
# 61613  6Lv0uLFhPt6e4qcmoeltAq        Robben Ford           Ain’t Nobody Home
# 61614  4PtUbfBR2U2BC0uUrT9hnM    No Te Va Gustar                    Todo Mal
# 61615  4PtUbfBR2U2BC0uUrT9hnM  Ciro y los Persas                    Todo Mal
# 61616  762E489aCXNDuRg1sZaWmC            Artemas              time alone w u
#
#           genre  year
# ...

# %%
# En resumen:

filtro_anio = (df['year'] >=2005) & (df['year'] <= 2009)
filtro_genre = df['genre'].isin(['hip-hop','rock','latin','pop'])

df_filtrado = df[(filtro_anio & filtro_genre)]
df_filtrado
# Out:
#                            id    artist_name  \
# 9177   1PS1QMdUqOal0ai3Gt7sDQ     Kanye West
# 9178   1PS1QMdUqOal0ai3Gt7sDQ     Jamie Foxx
# 9179   0jukvcN4fAGAgtkYVgLR9Z           SFDK
# 9180   2dxjKgT0li4qBI3QwuN9Ih     Kanye West
# 9181   2dxjKgT0li4qBI3QwuN9Ih    Lupe Fiasco
# ...                       ...            ...
# 19425  3h4JgBHcWM7A4CBVI6csau        Skillet
# 19426  0nx12KXHohiyLRqO5qfV2k  Mark Knopfler
# 19427  6gVH9jHl5Xpxxl4gVVrEkE        Nirvana
# 19428  6ZpbDCTXLlorzMgv8BEAHu      New Limit
# 19429  3K2dcFU3Wc2yAtC74b7d0H          Kryss
#
#                                            track_name    genre  year
# 9177                                      Gold Digger  hip-hop  2005
# 9178                                      Gold Digger  hip-hop  2005
# 9179                                     El Niño Güei  hip-hop  2005
# 9180                                    Touch The Sky  hip-hop  2005
# 9181                                    Touch The Sky  hip-hop  2005
# ...

# %%
#df_filtrado.to_json('datos_filtrados.json', orient='records')

# %%
lista = list(df_filtrado['artist_name'])
#lista_sin_duplicados = list(dict.fromkeys(lista))
lista_sin_duplicados = list(set(lista))
print(len(lista))
print(len(lista_sin_duplicados))
lista_sin_duplicados
# Out:
# 6915
# 2429
# ['Billy Danze',
#  'Jurassic 5',
#  'ANOHNI',
#  'Dr. Dre',
#  'Vybz',
#  'Cris Delanno',
#  'TOOL',
#  'Santiago Cruz',
#  'Jessie Morales',
#  'Los Fundamentalistas del Aire Acondicionado',
#  'Fulanito',
#  'Big Shug',
#  'Los Rebujitos',
#  'Devin The Dude',
#  'Mister Modo',
#  'Yung L.A.',
#  'Eneyser',
#  'Allen Halloween',
#  'Norah Jones',
#  'Primus',
#  'José Feliciano',
#  'Agua Marina',
#  'Niña Pastori',
#  'Mrigo',
#  'Baby Bash',
#  'Street Sweeper Social Club',
#  'Bow Wow',
#  'Ben Harper And The Innocent Criminals',
#  'Owl City',
#  'Nicole Wray',
#  'Despistaos',
#  'Lizz Wright',
#  'Aim',
#  'Decos',
#  'Marta Quintero',
#  'Zuti',
#  'Mike Jones',
#  'Jhonny Rivera',
#  'Makano',
#  'Sambomaster',
#  'Adrián Berra',
#  'Lou Fresh',
#  'Fleetwood Mac',
#  'Asaf Avidan',
#  'Bone Brothers',
#  'Logan',
#  'Andrés Cepeda',
#  'Flyleaf',
#  'Manafest',
#  'Sandy & Papo',
#  'Shaun Escoffery',
#  'Blaggards',
#  'Lord Infamous',
#  'Montana Trax',
# ...

# %%
with open("lista_artistas.json", "w", encoding="utf-8") as archivo:
    json.dump(lista_sin_duplicados, archivo, indent=4, ensure_ascii=False)
